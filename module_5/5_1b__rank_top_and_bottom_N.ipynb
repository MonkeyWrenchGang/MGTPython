# %% [markdown]
# <a href="https://colab.research.google.com/github/MonkeyWrenchGang/MGTPython/blob/main/module_5/5_1b__rank_top_and_bottom_N.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # Ranking, Top & Bottom N Records
#
#
# ---
#
# In this notebook we'll hop on dealing with ranking and selecting top & bottom records based on a numeric column.
#
# 1. Ranking
# 2. Nlargest
# 3. Nsmalles

# %%
from IPython.core.display import display, HTML
from IPython.display import clear_output
display(HTML("<style>.container { width:90% }</style>"))
import warnings
warnings.filterwarnings('ignore')
# ------------------------------------------------------------------
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
# ------------------------------------------------------------------
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %matplotlib inline
# Out:
# <style>.container { width:90% }</style>

# %%
nba = pd.read_csv("/content/gdrive/MyDrive/2022-MGT/nba.csv")
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics    0.00       PG 25.00    6-2  180.00
# 1    Jae Crowder  Boston Celtics   99.00       SF 25.00    6-6  235.00
# 2   John Holland  Boston Celtics   30.00       SG 27.00    6-5  205.00
# 3    R.J. Hunter  Boston Celtics   28.00       SG 22.00    6-5  185.00
# 4  Jonas Jerebko  Boston Celtics    8.00       PF 29.00   6-10  231.00
#
#              College     Salary
# 0              Texas 7730337.00
# 1          Marquette 6796117.00
# 2  Boston University        NaN
# 3      Georgia State 1148640.00
# 4                NaN 5000000.00

# %% [markdown]
# ## Rank Smallest to Largest
#
#
# ---

# %%
nba["salary_rank_smallest_to_largest"] = nba['Salary'].rank()
nba[["Name","Team","Age","Salary","salary_rank_smallest_to_largest"]].sort_values("salary_rank_smallest_to_largest").head(5)
# Out:
#                        Name                  Team   Age    Salary  \
# 32   Thanasis Antetokounmpo       New York Knicks 23.00  30888.00
# 291         Orlando Johnson  New Orleans Pelicans 27.00  55722.00
# 130            Phil Pressey          Phoenix Suns 25.00  55722.00
# 135           Alan Williams          Phoenix Suns 23.00  83397.00
# 175            Jordan McRae   Cleveland Cavaliers 25.00 111196.00
#
#      salary_rank_smallest_to_largest
# 32                              1.00
# 291                             2.50
# 130                             2.50
# 135                             4.00
# 175                             5.00

# %% [markdown]
# ## Rank largest to smallest

# %%
# rank defaults to largest to smallest 
nba["salary_rank_largest_to_smallest"] = nba['Salary'].rank(ascending=False)
nba[["Name","Team","Age","Salary","salary_rank_largest_to_smallest","salary_rank_smallest_to_largest"]].sort_values("salary_rank_largest_to_smallest").head(5)
# Out:
#                 Name                 Team   Age      Salary  \
# 109      Kobe Bryant   Los Angeles Lakers 37.00 25000000.00
# 169     LeBron James  Cleveland Cavaliers 31.00 22970500.00
# 33   Carmelo Anthony      New York Knicks 32.00 22875000.00
# 251    Dwight Howard      Houston Rockets 30.00 22359364.00
# 339       Chris Bosh           Miami Heat 32.00 22192730.00
#
#      salary_rank_largest_to_smallest  salary_rank_smallest_to_largest
# 109                             1.00                           446.00
# 169                             2.00                           445.00
# 33                              3.00                           444.00
# 251                             4.00                           443.00
# 339                             5.00                           442.00

# %% [markdown]
# ## Select TOP N records using nlargest()
#
#
# ---
#
#
# Who are the top 5 players based on Salary?

# %%
nba[["Name","Team","Age","Salary"]].nlargest(5, 'Salary')
# Out:
#                 Name                 Team   Age      Salary
# 109      Kobe Bryant   Los Angeles Lakers 37.00 25000000.00
# 169     LeBron James  Cleveland Cavaliers 31.00 22970500.00
# 33   Carmelo Anthony      New York Knicks 32.00 22875000.00
# 251    Dwight Howard      Houston Rockets 30.00 22359364.00
# 339       Chris Bosh           Miami Heat 32.00 22192730.00

# %% [markdown]
# ## Select BOTTOM N records using nsmallest()
#
#
# ---
#
#
# Who are the bottom 5 players based on Salary?

# %%
nba[["Name","Team","Age","Salary"]].nsmallest(5, 'Salary')
# Out:
#                        Name                  Team   Age    Salary
# 32   Thanasis Antetokounmpo       New York Knicks 23.00  30888.00
# 130            Phil Pressey          Phoenix Suns 25.00  55722.00
# 291         Orlando Johnson  New Orleans Pelicans 27.00  55722.00
# 135           Alan Williams          Phoenix Suns 23.00  83397.00
# 175            Jordan McRae   Cleveland Cavaliers 25.00 111196.00
